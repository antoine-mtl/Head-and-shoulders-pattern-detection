# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('EUR_CAD.csv')
print(data.head())
# Out:
#    None   symbol        date  hour  openbid  highbid   lowbid  closebid  \
# 0     0  EUR/CAD  2017-07-02    19  1.47996  1.48164  1.47996   1.48058
# 1     1  EUR/CAD  2017-07-02    20  1.48058  1.48176  1.48028   1.48053
# 2     2  EUR/CAD  2017-07-02    21  1.48053  1.48130  1.48023   1.48129
# 3     3  EUR/CAD  2017-07-02    22  1.48129  1.48199  1.48106   1.48199
# 4     4  EUR/CAD  2017-07-02    23  1.48199  1.48226  1.48158   1.48218
#
#    openask  highask   lowask  closeask  totalticks
# 0  1.48129  1.48273  1.48129   1.48210         212
# 1  1.48210  1.48293  1.48165   1.48181         298
# 2  1.48181  1.48208  1.48141   1.48201         595
# 3  1.48201  1.48231  1.48137   1.48231        1910
# 4  1.48231  1.48246  1.48177   1.48240        2307

# %%
nombre_observation=data.shape[0]-30

# for i in range(nombre_observation):
for i in range(nombre_observation):

    data_version=data.iloc[i:i+30,]
    
    # This line is necessary for the plot to appear in a Jupyter notebook
    # %matplotlib inline
    # Control the default size of figures in this Jupyter notebook
    # %pylab inline
    pylab.rcParams['figure.figsize'] = (15, 15)   # Change the size of plots
    data_version["openbid"].plot(grid = True) # P

    name=str(data_version.iloc[0,2])+"H"+str(data_version.iloc[0,3])
    print(name)
    names="test/positif/"+name+"_graph_30_day.png"
#     plt.savefig(names,dpi=28)
    plt.savefig(names)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 2017-07-02H19
# Populating the interactive namespace from numpy and matplotlib
# 2017-07-02H20
# Populating the interactive namespace from numpy and matplotlib
# 2017-07-02H21
# Populating the interactive namespace from numpy and matplotlib
# 2017-07-02H22
# Populating the interactive namespace from numpy and matplotlib
# 2017-07-02H23
# Populating the interactive namespace from numpy and matplotlib
# 2017-07-03H0
# Populating the interactive namespace from numpy and matplotlib
# 2017-07-03H1
# Populating the interactive namespace from numpy and matplotlib
# 2017-07-03H2
# Populating the interactive namespace from numpy and matplotlib
# 2017-07-03H3
# Populating the interactive namespace from numpy and matplotlib
# 2017-07-03H4
# Populating the interactive namespace from numpy and matplotlib
# 2017-07-03H5
# Populating the interactive namespace from numpy and matplotlib
# 2017-07-03H6
# ...

# %%
import numpy as np  
import pandas as pd  
from pandas_datareader import data as wb  
import matplotlib.pyplot as plt  





for abc in range(200):
    from scipy.stats import norm
    log_returns = np.log(1 + bitcoin.Close)
    u = log_returns.mean()
    var = log_returns.var()
#     drift = 0.001
    drift =(0.001 - (-0.001)) * random_sample() + -0.001
    
#     stdev = 0.0082497
#     stdev = 0.009
    stdev = (0.0082497 - (0.00)) * random_sample() + 0.00
    x = np.random.rand(10, 2)
#     Z = norm.ppf(np.random.rand(10,2))

    iterations = 1
    t_intervals = 30
    daily_returns = np.exp(drift + stdev * norm.ppf(np.random.rand(t_intervals, iterations)))
#     daily_returns=[]
#     for r in range(t_intervals):
#         daily_returns.append(1+(-0.03 + (0.03--0.03) * random_sample()))

    S0 = bitcoin.Close.iloc[-1]
    price_list = np.zeros_like(daily_returns)
    price_list[0] = S0
    for t in range(1, t_intervals):
        price_list[t] = price_list[t - 1] * daily_returns[t]
    lst=[]
    for i in price_list:
        lst.append(float(i))
#     print(lst)    
    # %matplotlib inline
    # Control the default size of figures in this Jupyter notebook
    # %pylab inline
    simulation_lst=lst

    df = pd.DataFrame(simulation_lst, columns =['pred']) 

    pylab.rcParams['figure.figsize'] = (15, 15)   # Change the size of plots
    df["pred"].plot(grid = True) 
    name=str(abc)

    names="tete_epaule2/validation/negatif/"+name+"_graph_30_day.png"
    plt.savefig(names)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# ...

# %%
-0.03 + (0.03--0.03) * random_sample()
# Out:
# -0.0037480404183129097

# %%
import numpy as np  
import pandas as pd  
from pandas_datareader import data as wb  
import matplotlib.pyplot as plt  
from scipy.stats import norm
from random import randint

for abc in range(200,300):
    try:
        from scipy.stats import norm
        log_returns = np.log(1 + bitcoin.Close)
        u = log_returns.mean()
        var = log_returns.var()
#         drift = 0.00020951
        drift = -0.00002
        stdev = 0.0082497
        x = np.random.rand(10, 2)
        Z = norm.ppf(np.random.rand(10,2))

        iterations = 1
        R1=randint(1,2)
        R2=randint(1,3)
        R3=randint(1,2)
        R4=randint(1,2)
        R5=randint(1,2)
        R6=randint(1,2)
        R7=randint(1,2)
        R8=randint(1,2)
        R9=randint(1,2)
        R10=randint(1,3)
        R11=randint(1,2)
        t_intervals = 30-R1-R2-R3-R4-R5-R6-R7-R8-R9-R10-R11
        if t_intervals < 0:
            t_intervals=2
        daily_returns = np.exp(drift + stdev * norm.ppf(np.random.rand(t_intervals, iterations)))
        S0 = bitcoin.Close.iloc[-1]
        price_list = np.zeros_like(daily_returns)
        price_list[0] = S0
        
        for t in range(1, t_intervals):
            price_list[t] = price_list[t - 1] * daily_returns[t]

        lst=[]
        for i in price_list:
            lst.append(float(i))
        print(lst)    

        A=(0.03 - (0.02)) * random_sample() + 0.02
        print(A)
        # A=0.02
        X=(0.01 - (0.01)) * random_sample() + 0.01
        
        multiplicateur=(2 - (1.3)) * random_sample() + 1.3
        
        def list_generation(valeur_base=int(S0),gap_day=R1,A=0.02):
            alist=[]
            R1a=[]
            cap=1
            for i in range(0,(gap_day-1)):
                ca=((A - (-0.005)) * random_sample() + (-0.005))+1
                cap=ca
                R1a.append(ca)
            R1a.append(A/cap+1)

            for i in range(0,gap_day):
                rf=valeur_base*(R1a[i])
                alist.append(rf)
            return alist
        
        a=list_generation(valeur_base=lst[-1],gap_day=R1,A=A)
        print(A)
        # print(a)
        b=list_generation(valeur_base=a[-1],gap_day=R2,A=X)
        # print(b)
        c=list_generation(valeur_base=b[-1],gap_day=R3,A=-A)
        # print(c)
        d=list_generation(valeur_base=c[-1],gap_day=R4,A=X)
        # print(d)
        e=list_generation(valeur_base=d[-1],gap_day=R5,A=multiplicateur*A)
        # print(e)
        f=list_generation(valeur_base=e[-1],gap_day=R6,A=X)
        # print(f)
        g=list_generation(valeur_base=f[-1],gap_day=R7,A=-multiplicateur*A)
        # print(g)
        h=list_generation(valeur_base=g[-1],gap_day=R8,A=-X*multiplicateur*(1+A)**10)
        
        # print(h)
        i=list_generation(valeur_base=h[-1],gap_day=R9,A=A)
        # print(i)
        j=list_generation(valeur_base=i[-1],gap_day=R10,A=X)
        # print(j)
        k=list_generation(valeur_base=j[-1],gap_day=R11,A=-A*(1+A)**5)
        # print(k)


        simulation_lst=lst+a+b+c+d+e+f+g+h+i+j+k
        # print(simulation_lst)

        df = pd.DataFrame(simulation_lst, columns =['pred']) 
        # %matplotlib inline
            # Control the default size of figures in this Jupyter notebook
        # %pylab inline
        pylab.rcParams['figure.figsize'] = (15, 15)   # Change the size of plots
        df["pred"].plot(grid = True) # 
        name=str(abc)

        names="tete_epaule2/train/positif/"+name+"_graph_30_day.png"
        plt.savefig(names)
    except:
        abc=abc-1
        pass
# Out:
# [8885.3, 8928.15386521886, 8877.581322813878, 8848.390829049515, 8974.53442538561, 9068.986867750915, 9108.396485435234, 9107.70807948086, 9107.646432390355, 9119.024397775167, 9184.397693716994, 9279.010090140358, 9269.755036349905]
# 0.02689051663041467
# 0.02689051663041467
# Populating the interactive namespace from numpy and matplotlib
# [8885.3, 8820.365634422731, 8847.044798960906, 9053.774667211504, 9032.267816425716, 8931.736980870115, 8954.865891832676, 8792.63047555677, 8846.980351570974, 8917.26000385628, 8954.95708697558, 8934.384640596798, 9000.734414514436, 8977.832502896123, 8932.390634262145, 8836.53857068678, 8796.210784653504, 8806.534965889401, 8922.029415539184]
# 0.022611535140871646
# 0.022611535140871646
# Populating the interactive namespace from numpy and matplotlib
# ...
